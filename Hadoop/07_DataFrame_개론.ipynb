# %% [markdown]
# # DataFrame

# %% [markdown]
# ![image.png](attachment:20ff5e69-dd63-423b-bb27-f227bef75c82.png)

# %% [markdown]
# - DataFrame은 행과 열로 이루어진 구조화된 데이터이다.
# - 내부적인 연산과정에서는 RDD로 변경되어 동작한다.
# - 광범위한 데이터 형식과 소스를 지원한다.
# - 기존 개발자들에게 친숙한 SQL과 Pandas API를 제공해 준다.
# - 스키마(데이터의 구조)가 존재하기 때문에 Spark가 실행 계획을 최적화 하기에 유리하다.
# - 특히 pyspark는 RDD와 DataFrame간 성능차이가 크기 때문에 불가피한 경우가 아니라면 DataFrame을 사용한다

# %% [markdown]
# ![image.png](attachment:4cf3c83d-2cff-4cf2-94ad-9912b654193a.png)

# %% [markdown]
# - scala Dataset문서 확인

# %% [markdown]
# ## DataFrame Catalyst Optimizer 동작 과정
# ![catalyst_optimizer.jpg](attachment:275690f8-1899-4847-9bd9-65fa5aa2b0ca.jpg)
